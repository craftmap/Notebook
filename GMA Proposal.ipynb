# %% [markdown]
# # Provided Overview
# Graduate Mentoring Assistantships
# College Guidelines | October 30, 2018
# The BYU Graduate Studies Office (GSO) supports the Graduate Mentoring Assistantships that are intended to provide funding for graduate students to mentor undergraduate students in scholarly work. Each college has the responsibility to create their own guidelines and deadlines, and to provide a rank ordered list of proposals to the GSO, who then makes final funding decisions. A summary of GSO requirements and guidelines for the Ira A. Fulton College of Engineering are provided below.
#
# ELIGIBILITY: Full-time faculty in the Ira A. Fulton College of EngineeringPURPOSESupport graduate students to mentor undergraduates in scholarly work
#
# FORMAT: Up to 3 pages plus budget and references
#
# PROPOSAL CONTENT: Proposals should include a clear, coherent, concise description of the scholarly project; explain how the award will enable students to deepen their understanding of the truths of their discipline; describe how graduate students will mentor undergraduates; describe how the funds enable the project, and the distinctive features enabled by the funding if done in conjunction with other projects; list expected outcomes, and provide a detailed project budget
#
# BUDGET: Up to $15,000 in direct support of the project, including student wages, project-related supplies, and mentoring-relevant travel
#
# DURATION: Up to one year from when the funds are awarded
#
# DEADLINE: December 1
#
# SUBMISSION: Send proposals to Larry Howell, associate dean, at lhowell@byu.edu
#
# **PROGRAM SUMMARY**
#
# The Graduate Mentoring Assistantships are intended to:
# - Support scholarship that meets the highest standards and the vision for Inspired Learning articulated by President Worthen
# - Assist faculty to mentor graduate students who in turn mentor undergraduates
# - Enable students to participate in extraordinary and even life-changing scholarly projects
# - Provide students opportunities to demonstrate maturity, initiative and independence

# %% [markdown]
# # My Project
#
# - Description of Project
#     - Rotor on rotor interactions in forward flght conditions.
#     - "What is problem, WHy important? Whats solution and why its impactful. Electric is leading to more
#
# - How award will enable student to deepen understanding (me and undergrads)
#     - teaching concepts helps solidify them
#     - Expand the scope of the research to involve more hands on emperical testing
#     - Experimental design, varience, similarity principles. Fundamental. Validate results compare to Published. Class work doing it for real. Writing a scientifc paper, new
#
# - How I will mentor undergraduates (what I do)
#     - Weekly meeting
#     - Teaching basics of related material
#     - Answering questions
#     - Hands on experience
#
# - How funds enable project and distinctive features enabled by funding
#     - Working in novel area without established funding pattern. Its a startup buisnesses, cutting edge
#     ?? No money no project
#
# - Outcomes
#     - State of the art VPM validation
#     - Two undergraduates gain hands on experience with new wind tunnel that is reserved exclusivley for research.
#     - Co-author?
#     - Produce valuable and novel data for important insights into VTOL performance/noise
#     - Emperical data to validate MS student CFD and PhD students VPM
#
# - Detailed Budget
#     - AIAA Partial Travel support
#     - My wages and undergraduates
#
#     Pictures (Eduardo VPM, windtunnel)
#  - Include Timeline
#
# # Dr Ning
# - Lindsey being able to mentor undergraduate. Coauthor.
#  - 4 K to undergrads. Other 11 k for me. 1 K trasportation.
#  -  Use of new wind tunnel
#  - Mention everything, latex, git,

# %% [markdown]
# # Outline of Proposal
# ## Motivation
# - Recent advances in electric aircraft technologies has led to significant changes in the design possiblities of next generation vehicles.
# - Vertical take of and landing (VTOL) vehicles are one design that has been made possible by the advancement of these electric technologies.
# - Distributed electric propulsion introduces inter-propeller aerodynamic and aeroacoustical interactions that can decrease efficiency and increse noise.
#     - Efficiency is of key importance as battery technologies are still limited and efficiency directly effects key perfomance metrics of aircraft, like range.
#     - With several next generation electric aircraft being designed for use in urban settings, noise is of key imporance.
# - Current methods that can be used to study these interactions–namely high fidelity computational fluid dynamic and empirical testing–are very computationally prohibitive for conceptual design.
# - Our aim is to create a mid-fidelity tool for use in studying these interactions and to publish high quality emperical data that can be used in validation of this tool and of other similar tools.
#
# ## Student Involvement/Research
# - The unique design of this research project has already allowed for great mentoring of junior ME student Lindsay Lawless, who over the last semester has been able to gain significant hands on experience with the new byu windtunnel and other department resources reserved exclusively for research.
# - Due to the quick learning and impressive results Lindsay has already produced the current plan is to have her oversee and supervise the mentoring of a new sophore student, Richard Tainter, who is joining the project next semester.
#     - She has already participated and helped in the project plan for the upcoming semester and specifically laying out the goals and roles Richard will fill.
#     - Both undergraduates will still continue to be mentored and meet regularly with Austin Schenk who is the MS student over the project who will recieve any extra help from Eduardo Alvarez(PhD) or Dr Ning who are respectiviely the PhD student and PI over the project.
# - On this project Lindsay and Richard will be able to apply many of the core fundamentals that are taught in classes to a real world project. Fundmentals such as experimental design, research paper construction, and experimental documentation will be solidified through hands on experience.
# - Results will be measured in weekly meetings with Austin, weekly presentations/discussion in front of the entire lab, as well as documentation in a required lab notebook.
# - Currently with this area of research being new and cutting-edge there is not currently an established pattern of funding.
#     - Much of the intrest in this area has mainly been by start-up companies, with larger companies just begining to show an interest.
#     - Electric aircraft has historically been considered a novelty that was only pursued by start-ups and since there has only recently been interest shown by large companies, due to the electric propulsion advancements, there is not an established funding pattern yet.
#     - As such, this funding will help facilitate Austin, Lindsay, and Richard to become key-players in a nascent industry.
#
#
# ## Outcomes
# - The mentoring of a junior and sophore student  who are both interested in pursueing graduate degrees.
# - Hands on experience with principles taught in class and experience with state-of-the-art wind tunnel.
# - One major outcome of this research will be validation which will be published and directly used in our lab for the  validation of Austin's computer simulations and for validating Eduardo Alvarez's Vortex Particle Model.
# - Due to the significant contributions already made by Lindsay and her plans of continued involvement with the project she will have the opportunity to write part of a journal paper and be a co-author with Austin on his jornal paper which will include parts of these empirical test.
# - A rare opportunity for a junior to co-mentor a sophmore student who is just begining with research.
# - As a requirment in the lab all three students involved will be required to submitt a journal quality end of semester report, documenting and commenting on thier research, which will go through multiple peer reviews and a final evaluation by Dr. Ning. This allows student to learn how to consolidate months worth of work into a concise and clear verbal presentation of their results.
# - Initial exposure to reserach for two motivated undergraduates that both have expressed a desire and plan to pursueing higher education after graduation.
# - Both Lindsay and Richard plan on attending the Utah Conference on Undergraduate Research to present their results.
