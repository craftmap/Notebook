# %% [markdown]
# # Process
#
# ## Initial
# Follow Tutorial but with these changes in dimensions:
#      * Z is V_inf direction
#      * 3d-CAD  > RC YZ > Sketch > Create Rectangle ~ 0.005 In front of and behind prop, from y axis to ~0.0025 beyond tip.
#     * 10 Diameter bullet shape: Based on Doc > StarCCM+ > Simualting Physics > Guidlines for applying Simcenter StarCCM+ > Guidelines for aerodynamic calcuations > Incomp External Aero !!
#     * 20 Diameters downstream see Acoustic Prediction of High Speed Propeller Noise Using URANS and a Ffowcs Williams-Hawkings Solver
#     * RC XZ >sketch > 10*.254 radius 1/4 circle > $10*.254x20*.254$ Rectangle: Create only half domain
#     * RC Sketch 2 > Create revolve > set body interation NONE > 360 about z
#
# ## Designate Boundary Conditions and Interfaces
# Regions>Region>Boundaries> RC and set
# FluidIN> Velocity inlet
# FluidOUT> Pressure outlet
# FluidFREE > Freestream
#
# Create interfaces > Select outer rotating surface in both region and RC > create interface
#
#
# ## Define Physics Continua
# RC Continua > New Physics
# Double Click Models
# - 3D, Implicit unsteady, gas, Coupled, Ideal gas, Turbulent, k-omega turb,
#     * 3D, unsteady, gas, turbulent: By definition of what we are modeling
#     * Coupled
#
#     * Ideal gas
#
#     * K-omega turb
#
# Freestream
# 6000 RPM, at J = 0.6 based on UIUC. therefore Vinf = 15.24
# - But I need to do dynamic similarity and calculate a new one
#
# Motion
# tools> motion >rc rotation
# rc region Rotate > Physics Values > Motion Specs > select Rotation
# Go into regions and set initial Mach, Velocity, flow dir, rotation etc.
# Set Step size in solvers > implicit unstead 9E-5
#
#
#
# ## Create Mesh
# Super simple, just see old sim for parameter values
# - Operations Automated mesh
#     * Set values based on other simulation
#
#
# ## Create Reports
# - RC reports new thrust, moment: then for both just select the propeller region
# - RC report and select "create monitor and plot"
#
#
# ## Run simulation
# * Super Computer
#
# ## Visualization
#
# ## Additional Concerns
# - Physic reference values. Am I matching reynolds number?
#
#
# - Updating simulation for a new prop. Import into CAD. Delete old. Rename new one as old. UPDATE CAD. Delete old prop PART. Right click Prop in bodies. Create part from body. Set tesselation params (see HOw do I imporve the initial tessellation quality of my part?). Now update Subraction. NOW UPDATE MESH BL Custom Control, select propeller. Done
