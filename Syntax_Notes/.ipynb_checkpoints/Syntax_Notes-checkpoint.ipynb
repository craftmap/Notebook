# %% [markdown]
# # Terminal
# |TERMINAL |
# |---| :---: |
# |pwd| Print Working Directory|
# |ls| List Files|
# |cd |Change Directory|
# |mkdir |Make Directory|
# |touch| Make File|
# |cp| Copy|
# |mv| Move|
# |rm| Remove|
# |rm -rf|recursive, force|
# |Ctrl C| abort|
# |cd -| last direc|
# |tab| auto complete|
# |Ctrl R| search|
# |!!| run last com|
# |!cat| last cat com|
# |!cat:p| print it|
# |!$| last arg|
# |^wrong^right| last com and rerun|
# |nano ~/.bash_profile| my_profile|
# |source .bash_profile| to set it|
# |pip list||
# |man ls| |
# |cp -R {path} .| Copy path folder to current folder|
# |mv <old_name> <new_name>| Rename|
#
#
# - history | grep 'searchword'
#     - then run it with !'number'
#
#
# |NANO|
# |---| --- |
# |Ctrl - ; Ctrl v| Jump to end|
# |Ctrl a| Beginning of line|
# |Ctrl e| End of Line|
# |Ctrl u| delete line|
# |Ctrl k| delete to end|
# |Ctrl w| delete to front|
# |Ctrl o ; ENTER|  save|
# |Ctrl x| exit|
#
# ## Errors and Fixes
# - MPI error run:  '~$  export TMPDIR=/tmp'

# %% [markdown]
# # Supercomputer
# -
# - Login:
# 	ssh schenkau@ssh.fsl.byu.edu
# 	Password: Same as mybyu
# 	**now you are in bash**
# Moving Files:
# 	- Load file onto supercomputer
# 		scp file schenkau@ssh.fsl.byu.edu:/fslhome/schenkau/compute
# 	- Download file from supercomputer
# 		scp schenkau@ssh.fsl.byu.edu:/fslhome/schenkau/compute/file  ~/Desktop   or  /.
# 	- Copy/Renaming/Moving
# 		cp FILEPATH_of_file  desired_location(or . for current location)
# 			example: cp ../compute/AR_sweep/a7_8.sim .
# Submitting Jobs:
# 	- General
# 		sbatch  FILE.sh
# 	- Star-CCM+ Example
# 		sbatch Run.sh Macro.java Prop_simulation.sim
# 	- Status
# 		scontrol show job ########a
# Interactive node:
# 	- Star-CCM+
# 		ssh -X schenkau@ssh.fsl.byu.edu
# 		module load starccm+/11.04.010
# 		starccm+
# Modules:
# 	module avail python (available python packages)
# 	module load python/2/7 (load package)
# 	module unload
# 	module list keyword
# 	to install
# 	python setup.py install --user
#
# Linux/Bash:
# 	- Pictures --> Video
# 		convert -delay 8 FILENAME/*.jpg VIDEONAME.gif
# 	- Rename Files (Get rid of "pic")
# 		for i in pic*.jpg; do SUBSTRING=$(echo $i | cut -d'c' -f 2); mv $i $SUBSTRING; done;
#  	-Add 00
# 		for i in ?.jpg; do mv $i "00""${i}"; done;
#
#
#
# Display Error : "Warning: untrusted X11 forwarding setup failed: xauth key data not generated"
# "/apps/starccm+/11.04.010/STAR-CCM+11.04.010/star/bin/nbexec: WARNING: environment variable DISPLAY is not set"
# Solution: Update XQuartz

# %% [markdown]
# # Git
# -
# Update Folder
# - git pull origin master
# Add New Files
# - git status (check which neeed to be added)
# - git add -u (adds all including deleted files)
# - git add -A ( add only deleted files)
# Commit
# - git commit -m "...."
# Upload
# - git push origin
#
#
# Git basic Commands
# https://confluence.atlassian.com/bitbucketserver/basic-git-commands-776639767.html
#
# init, status, add 'filename', diff 'filename', q (exit diff mode), log, show HEAD (show last commit), checkout HEAD 'filename' (Restore to last commit), reset HEAD 'filename' (takes file off staging area), reset,
# branch, checkout 'filename' (move to branch), merge 'filename, branch -d 'branch name' (delete branch),  branch -r (list all remote branches), clone 'remote' 'dir', remote -v (print origin path), merge origin/master, push origin 'branchname', pu
#
# mv -vfk file.py newname.py (rename file)gir

# %% [markdown]
# # Python
#
# |Python|
# |---|---|
# |#| comment|
# |'''  '''| multi-line comment|
# |**| (power)|
# |# % #| (remainder)|
# |\' |to use  ' in a string|
# |len()| length|
# |.lower(), "   %s   " % (word),
# variable = raw_input("Prompt here")
# if      :     return     print;
# def():
# import, from '' import * (import everything and call func direct), list.append(), .index(), .insert(), for 'variable' in 'list':, dictionary["variable"]= value, del list[] or dictionary[], list.remove('item'), += (increment), list.pop(), list.remove(), del(list[]),
# print " ".join(list) (to format printing)
#
# print dict.items();
#
#
# I/O: my_file = open("output.txt", "r+")  (read and write, 'w', r)
# my_file.write("data to be written')
# my_file.close()
#
# my_file = open('output.txt','r')
# print my_file.read()
# my_file.close()
#
# range(stop)
# range(start, stop)
# range(start, stop, step)
#
# list[start:end:stride]
#
# bin, &(and), |(or), ^ (xor), ~(not   +1 then *-1), int(str, base#),
#
# EX:my_list = range(16)
# print filter(lambda x: x % 3 == 0, my_list)
#
# EX: evens_to_50 = [i for i in range(51) if i % 2 == 0]
# print evens_to_50
#
# EX: from datetime import datetime; now = datetime.now()
# not and or, !=,
# EX: dictionary["list"].remove('item')
# EX: for index, item in enumerate(list):
# EX: for a, b in zip(list_a, list_b):
# ## Examples
#
# EX: class Animal(object):
#     """Makes cute animals."""
#     is_alive = True
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
# zebra = Animal("Jeffrey", 2)
# giraffe = Animal("Bruce", 1)
# panda = Animal("Chad", 7)
#
# print zebra.name, zebra.age, zebra.is_alive
#
#
#
#
#
#
#
# Sample Battleship code
#
# from random import randint
#
# board = []
#
# for x in range(5):
#     board.append(["O"] * 5)
#
# def print_board(board):
#     for row in board:
#         print " ".join(row)
#
# print "Let's play Battleship!"
# print_board(board)
#
# def random_row(board):
#     return randint(0, len(board) - 1)
#
# def random_col(board):
#     return randint(0, len(board[0]) - 1)
#
# ship_row = random_row(board)
# ship_col = random_col(board)
#
#
# \# Everything from here on should go in your for loop!
# \# Be sure to indent four spaces!
# for turn in range(4):
#     print "Turn", turn+1
#     guess_row = int(raw_input("Guess Row:"))
#     guess_col = int(raw_input("Guess Col:"))
#
#     if guess_row == ship_row and guess_col == ship_col:
#         print "Congratulations! You sunk my battleship!"
#         break
#     else:
#         if (guess_row < 0 or guess_row > 4) or (guess_col < 0 or guess_col > 4):
#             print "Oops, that's not even in the ocean."
#         elif(board[guess_row][guess_col] == "X"):
#             print "You guessed that one already."
#         else:
#             print "You missed my battleship!"
#             board[guess_row][guess_col] = "X"
#         # Print (turn + 1) here!
#         print_board(board)
#         if turn == 3:
#             print "Game Over"
#
# Vowel Eliminator
# def anti_vowel(text):
#     final = ''
#     vowels = 'aeiouAEIOU'
#     for i in text:
#         if i not in vowels:
#             final = final + i
#     return final
# print anti_vowel("Hey look Words!")

# %% [markdown]
# # General
# -
# - General
# Citrix Login:
# 	et.byu.edu\schenkau
# 		PASSWORD: a-5
# Link J-drive:
#  	Open finder > Go > Connect to server
# 	Finder > command K
#
# XFOIL
# HWK 2
# - naca 2412 -> oper -> v -> seqp -> pacc -> ppax (set Axes) -> aseq 'lower' 'upper' 'step' (angle of attack) -> pdel -> 0 (reset)
# gdes (plot shape)
#  selig s1223
# eppler 211
# clark y
#
# VMWare: Keyboard/Mouse not registering on VM
#     Go to System Preferences > Security & Privacy > Accessibility > Check on VMware to let it access computer controls
