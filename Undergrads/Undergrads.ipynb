# %% [markdown]
# # Undergraduate Researchers
#
# <img src="img/Test.jpg" alt="pic here" style="width: 400px;"/>
#
# ## Notes from Semester end meeting
# For entry level undergraduates
# 1)  Tutorial (Volunteering)
# 2) 497R Reproducing results
# 3) Mentored research project: worked with grad student on their project
# 4) Independent self-driven project
# Goal: Co-author Paper
#
# ## Juan Cuevas
# ### Contact
# (801) 368-9381; jac.cuevas77@gmail.com;
#
# ### Plan
# - Helped with collecting experimental data
# - Helped with calibration of equipment
#
# - Willing to help more!
#
# ## Lindsay
# ### Contact
# lindsaylawless17@gmail.com;
# ### Plan
# - Time: 10 hours
#  M/W 10-11; T/Th 9-12; F 9-11
#
# - Dr Ning
#     - Intro to Aeronautical Engineering
#     - Intro to Aerodynamics
#     - Julia
#
#
# - Julia: Begin by grabbing data from UIUC and ploting
#     - Matlab: Grabit
# - Run
#     - Single Propeller APC 10x7 thin electric
#         - Need close agreement with UIUC
#
# - Read
#     - Prospectus?
#     - UIUC Paper
#     - PIV paper
#
# - ME:
#     - Talk to Kevin about windtunnnel scheduling: jaredeoliphant@gmail.com (Plans to be done by the start of classes)
#     - Figure out wind tunnel corrections
#     - APC 10x7; Papers; Current Draw; Purchase?
#     - Install Julia, git, etc
#
#
#  ### 9/3/18
#  - ME: Ask Kevin about windtunnel instrumentation?
#  - Goals: Jupyter, Windtunnel,
#
#
#  ## Charlie Tainter
#  ### Contact
#  richardtainter96@gmail.com
#  702-858-6023
#  ### Plan
# - Together Tues: 10-12
# Monday and Wednesday 12-3
